# %% [markdown]
# Instruction the pr-work #4
#
# `TODO`: make the final .ipynb file in format `"{second_name}_{first_name}_{group_id}__pr_4.ipynb"`
#
# First name - Volodymyr
#
# Second name - Donets
#
# Group - KU-21

# %% [markdown]
# # Task Description
#
# ## Overall description
#
# In this work we'll learn the essential techniques for handling non-numeric data. You will practice extracting features from dates, manipulating raw text, and transforming categorical variables into machine-learning-ready numeric formats.
#
# ## Detailed description
#
# ### I. Working with Datetime
#
# 1. Select and load few a `.csv` datasets containing at least one date/time column (if your current dataset lacks one, artificially add a date column or merge it with another dataset, or simply use one from the lesson).
# 2. Convert the string representation of the date/time into a proper `pandas` datetime object using `pd.to_datetime()`.
# 3. Extract at least three new useful features from the datetime column (e.g., year, month, day of the week, hour, or an `is_weekend` boolean flag).
# 4. Drop the original raw datetime string column from the working DataFrame.
#
# ### II. Working with categorical data
#
# 1. Identify nominal (unordered) and ordinal (ordered) categorical columns in your dataset.
# 2. Apply Label Encoding (or manual mapping) to at least one ordinal categorical column (e.g., mapping 'low', 'medium', 'high' to 0, 1, 2).
# 3. Apply One-Hot Encoding (using `pd.get_dummies()` or `sklearn`'s `OneHotEncoder`) to at least one nominal categorical column.
#
# ### III. Working with other string data
#
# 1. Identify a column containing unstructured text, mixed formats, or string artifacts (e.g., "$1,000", "  Category A  ", "ID-4920").
# 2. Perform basic string operations using the `.str` accessor (e.g., lowercasing, stripping trailing/leading whitespaces, replacing specific characters).
# 3. Extract a specific pattern using Regular Expressions (Regex) via pandas string methods and save the extracted data as a new feature column.
#
# ### IV. Balanced encoding
#
# 1. Identify a categorical column with high cardinality (many unique categories), show cardinality statistics by categorical columns.
# 2. Apply a balanced/advanced encoding technique (such as Target Encoding, Frequency/Count Encoding, or Hashing) to this column.
# 3. Observe how this affects the dataset compared to standard One-Hot Encoding.
#
# ## Important
#
# 1. Do your work in sections, which is identical to the task.
# 2. Do NOT mess with a single column, such works will be worth 0 !!! If you can't work with Jupyter Notebook use .py scripts, but your report should be in a .pdf file. Or just ask for help, I'm not a some kind of monster.
#
# ## How to get max points without personal work presentation
#
# 1. **Explain the "Why":** Don't just run the code. In Markdown cells, briefly explain *why* you chose a specific encoding method for a specific column (e.g., why One-Hot Encoding was better than Label Encoding for a particular feature).
# 2. **Before and After Analysis:** Show the `.shape` and `.dtypes` of your DataFrame before you start encoding, and after you finish. Write a sentence explaining how your categorical transformations impacted the dimensionality (number of columns) of your dataset.
# 3. **Final Proof:** At the very end of your work, show a final state of a fully cleaned DataFrame and use `.info()` or a custom check to prove that absolutely all columns are now strictly numeric types (`int`, `float`) and ready for a machine learning model.

# %% [markdown]
# # Additional readings:
#
# 1. [Medium simple examples with visualization](https://medium.com/aiskunks/categorical-data-encoding-techniques-d6296697a40f)
# 2. [ADVANCED: Types of encoding](https://feature-engine.trainindata.com/en/1.7.x/user_guide/encoding/)
# 3. [Kaggle: Overview of encoding techniques](https://www.kaggle.com/code/shahules/an-overview-of-encoding-techniques#Method-3-:-Feature-hashing-(a.k.a-the-hashing-trick)--)
# 4. [BOOK: Python Feature Engineering Cookbook](https://www.amazon.com/Python-Feature-Engineering-Cookbook-transforming-dp-1804611301/dp/1804611301?_encoding=UTF8&me=&qid=1664914659)

# %% [markdown]
# # 1. Import dependencies

# %%
import pandas as pd
import numpy as np
