# %% [markdown]
# Instruction the pr-work #3
#
# `TODO`: make the final .ipynb file in format `"{second_name}_{first_name}_{group_id}__pr_3.ipynb"`
#
# First name - Volodymyr
#
# Second name - Donets
#
# Group - KU-21

# %% [markdown]
# # Task Description
#
# ## Overall description
#
# In this work we'll learn the basic techniques of working with missing values.
#
# ## Detailed description
#
# ### I. Prepare the data with missing values.
#
# 1. Carefully study the code example shown in this work.
# 2. Move your .csv file from the previous work to the `src` dir
# 3. Run a function `make_missing_values` to make missing values more appear more often
#    (and make your working DataFrame appear shorter).
# 4. Load the new DataFrame with artificially added missing values.
#
# ### II. Working with missing values
#
# 1. Remove rows with any missing values (Do NOT same results in the working DataFrame).
# 2. Remove cols with any missing values (Do NOT same results in the working DataFrame).
# 3. Remove rows with the specific number (or percent) of missing values (Do NOT same results in the working DataFrame).
# 4. Execute back filling of missing values (Do NOT same results in the working DataFrame).
# 5. Execute front filling of missing values (Do NOT same results in the working DataFrame).
# 6. Execute filling by a specific values (median, mean, just value indicator like -1 for numerical or "missing" for object.
#
# ## Important
#
# 1. Do your work in sections, which is identical to the task.
# 2. Do NOT mess with a single column, such works will be worth 0 !!! If you can't work with Jupyter Notebook use .py scripts, but your report should be in a .pdf file. Or just ask for help, I'm not a some kind of monster.
#
# ## How to get max points without personal work presentation
#
# 1. **Explain the "Why":** Don't just run the code.
#    In Markdown cells, briefly explain *why* you would choose one filling/dropping method over another.
# 2. **Before and After Analysis:** For at least one numerical column, show the `.describe()` statistics before you fill the missing values, and after.
#    Write a sentence explaining how your filling method changed the standard deviation or mean.
# 3. **Final Proof:** At the very end of your work, show a final state of a fully cleaned DataFrame
#    and print a check proving there are exactly 0 missing values left.

# %% [markdown]
# # Data on Kaggle to select (please download .csv file in your working directory)
#
# `WARNING 1`: Some links might be outdated, so just search by the dataset name in www.kaggle.com
# `WARNING 2`: Please register on this site to be able to download the data
# `WARNING 3`: If you'll struggle with data, just ask teacher for help.
#
# 1. [Liver Cirrhosis Stage Classification](https://www.kaggle.com/datasets/aadarshvelu/liver-cirrhosis-stage-classification)
# 2. [Star Dataset for Stellar Classification](https://www.kaggle.com/datasets/vinesmsuic/star-categorization-giants-and-dwarfs)
# 3. [Fitness Classification Dataset](https://www.kaggle.com/datasets/muhammedderric/fitness-classification-dataset-synthetic)
# 4. [ECG Arrhythmia Classification Dataset](https://www.kaggle.com/datasets/sadmansakib7/ecg-arrhythmia-classification-dataset)
# 5. [Mushroom Classification Enhanced](https://www.kaggle.com/datasets/sakurapuare/mushroom-classification-enhanced)
# 6. [Dry Bean Dataset Classification](https://www.kaggle.com/datasets/nimapourmoradi/dry-bean-dataset-classification)
# 7. [Swarm Behaviour Classification](https://www.kaggle.com/datasets/deepcontractor/swarm-behaviour-classification) -- challenging one 270 Mb dataset
# 8. [Anemia Types Classification](https://www.kaggle.com/datasets/ehababoelnaga/anemia-types-classification)
# 9. [NASA: Asteroids Classification](https://www.kaggle.com/datasets/shrutimehta/nasa-asteroids-classification)
# 10. [Gold Price Prediction](https://www.kaggle.com/datasets/franciscogcc/financial-data)
# 11. [Possum Regression](https://www.kaggle.com/datasets/abrambeyer/openintro-possum/data)
# 12. [Student Performance](https://www.kaggle.com/datasets/nikhil7280/student-performance-multiple-linear-regression)
# 13. [Boston House Prices](https://www.kaggle.com/datasets/fedesoriano/the-boston-houseprice-data/data)
# 14. [Car Price](https://www.kaggle.com/datasets/hellbuoy/car-price-prediction)
# 15. [Medical Cost](https://www.kaggle.com/datasets/mirichoi0218/insurance)
# 16. [Crab Age Prediction](https://www.kaggle.com/datasets/sidhus/crab-age-prediction)
# 17. [Calculate Concrete Strength](https://www.kaggle.com/datasets/prathamtripathi/regression-with-neural-networking)
# 18. [Advertising dataset](https://www.kaggle.com/datasets/tawfikelmetwally/advertising-dataset)

# %% [markdown]
# # Installing & import dependencies

# %%
# %pip install numpy
# %pip install pandas

# %pip install matplotlib

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Tool functions

# %%
def make_missing_values(
    src_path: str,
    tgt_path: str,
    n_rows: int = 100,
    missing_per_col: float = 0.1,
) -> None:
    """
    This function loads your DataFrame and stores it as a separate .csv file for your experiments with missing data.
    
    :param src_path: Path to the original source .csv file to read.
    :param tgt_path: Path where the modified .csv file with missing values will be saved.
    :param n_rows: Number of rows to read from the source file.
    :param missing_per_col: The fraction of values to drop per column (e.g., 0.2 for 20% missing data). Must be between 0.0 and 1.0.
    :return: None
    """
    
    # 1. Load the specific number of rows from the source CSV
    df = pd.read_csv(src_path, nrows=n_rows)
    
    # 2. Calculate the exact number of missing values to inject per column
    # We use len(df) in case the source file has fewer rows than n_rows
    n_missing = int(len(df) * missing_per_col)
    
    # 3. Iterate through each column and inject NaNs randomly
    for col in df.columns:
        # Select random indices without replacement, so we don't pick the same row twice
        missing_indices = np.random.choice(df.index, size=n_missing, replace=False)
        
        # Assign NaN to the selected random indices for the current column
        df.loc[missing_indices, col] = np.nan
        
    # 4. Save the modified DataFrame to the target path
    df.to_csv(tgt_path, index=False)

# %% [markdown]
# # Example of usage

# %% [markdown]
# ## 1. Prepare the data

# %%
make_missing_values(
    src_path="./src/titanic_surv_data.csv",
    tgt_path="./src/miss_titanic_surv_data.csv",
)

# %%
df_miss = pd.read_csv("./src/miss_titanic_surv_data.csv")
df_miss.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0        892.0     3.0                              Kelly, Mr. James    male
# 1        893.0     3.0                                           NaN  female
# 2        894.0     2.0                     Myles, Mr. Thomas Francis    male
# 3        895.0     3.0                              Wirz, Mr. Albert    male
# 4        896.0     3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5    0.0    0.0   330911   7.8292   NaN        Q
# 1  47.0    1.0    0.0   363272   7.0000   NaN      NaN
# 2  62.0    0.0    0.0   240276   9.6875   NaN        Q
# 3  27.0    0.0    0.0   315154   8.6625   NaN      NaN
# 4   NaN    1.0    NaN  3101298  12.2875   NaN        S

# %%
df_miss.tail()
# Out:
#     PassengerId  Pclass                                               Name  \
# 95        987.0     3.0                         Tenglin, Mr. Gunnar Isidor
# 96        988.0     NaN  Cavendish, Mrs. Tyrell William (Julia Florence...
# 97        989.0     3.0                          Makinen, Mr. Kalle Edvard
# 98        990.0     NaN                       Braf, Miss. Elin Ester Maria
# 99        991.0     3.0                       Nancarrow, Mr. William Henry
#
#        Sex   Age  SibSp  Parch             Ticket    Fare Cabin Embarked
# 95    male  25.0    0.0    NaN             350033     NaN   NaN        S
# 96  female  76.0    1.0    0.0              19877     NaN   C46        S
# 97    male  29.0    NaN    0.0  STON/O 2. 3101268  7.9250   NaN        S
# 98  female  20.0    0.0    0.0             347471  7.8542   NaN        S
# 99    male  33.0    0.0    NaN         A./5. 3338  8.0500   NaN        S

# %%
df_miss.isnull().sum()
# Out:
# PassengerId    30
# Pclass         30
# Name           30
# Sex            30
# Age            42
# SibSp          30
# Parch          30
# Ticket         30
# Fare           30
# Cabin          85
# Embarked       30
# dtype: int64

# %%
df_miss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  70 non-null     float64
#  1   Pclass       70 non-null     float64
#  2   Name         70 non-null     object
#  3   Sex          70 non-null     object
#  4   Age          58 non-null     float64
#  5   SibSp        70 non-null     float64
#  6   Parch        70 non-null     float64
#  7   Ticket       70 non-null     object
#  8   Fare         70 non-null     float64
#  9   Cabin        15 non-null     object
#  10  Embarked     70 non-null     object
# dtypes: float64(6), object(5)
# memory usage: 8.7+ KB

# %% [markdown]
# # Practical tasks section
